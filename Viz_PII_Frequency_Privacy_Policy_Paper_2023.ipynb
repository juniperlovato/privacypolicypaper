# %% [markdown]
# <a href="https://colab.research.google.com/github/juniperlovato/privacypolicypaper/blob/main/Viz_PII_Frequency_Privacy_Policy_Paper_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd 
import ast
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import plotly.express as px
import collections 
from collections import Counter 
import re
from matplotlib.pyplot import figure
import random
import dash 
from dash import Dash, dcc, html, Input, Output
import plotly.express as px



#Sklearn
import sklearn as sk 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer


#NLTK
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import PorterStemmer
porter = PorterStemmer()
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.tokenize import RegexpTokenizer
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.metrics import BigramAssocMeasures
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures
from nltk.corpus import stopwords
from nltk import ngrams
from nltk.probability import FreqDist
from nltk.probability import DictionaryProbDist

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #Making a bag of words

# %%
texts = pd.read_csv('/pathname/ALLYEARS_pii_extracted.csv')

# %%
list_of_texts = texts['PII_Extracted'].tolist()

# %%
#Setup scikit vectorizer
vectorizer = CountVectorizer(min_df=1)
term_doc_matrix = vectorizer.fit_transform(list_of_texts)
vectorizer.get_feature_names_out()
# Out:
# array(['abilities', 'address', 'age', 'aids', 'alias', 'analyze',
#        'ancestry', 'attitudes', 'audio', 'beacons', 'behavior',
#        'behavioral', 'biological', 'biometric', 'breastfeeding', 'cancer',
#        'characteristics', 'child', 'childbirth', 'chiropractic',
#        'citizenship', 'color', 'combination', 'condition', 'cookies',
#        'coordinates', 'dentistry', 'diagnosis', 'disability', 'dna',
#        'education', 'employment', 'ethnic', 'exercise', 'face',
#        'faceprint', 'family', 'fingerprint', 'fingerprints', 'gender',
#        'genetic', 'geolocation', 'hand', 'health', 'height', 'hiv',
#        'household', 'identified', 'identifiers', 'inferences', 'initials',
#        'intelligence', 'interests', 'iris', 'irises', 'language',
#        'latitude', 'locate', 'location', 'longitude', 'medicine',
#        'mental', 'movements', 'name', 'nursing', 'olfactory', 'optometry',
#        'origin', 'palm', 'password', 'passwords', 'patient', 'pharmacy',
#        'physical', 'physiological', 'podiatry', 'predict',
#        'predispositions', 'preferences', 'pregnancy', 'professional',
#        'profiling', 'race', 'racial', 'radius', 'reliability', 'religion',
#        'retina', 'sex', 'signature', 'sleep', 'thermal', 'visual',
#        'voice', 'voiceprint'], dtype=object)

# %%
# Put BoW vectors into a new df
policy_texts_bow = pd.DataFrame(term_doc_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# %% [markdown]
# saving bag of words

# %%
policy_texts_bow.to_csv('/pathname')

# %% [markdown]
# # Getting Info about the bag of words

# %%
bow_1997 = pd.read_csv('/pathname')
bow_1998 = pd.read_csv('/pathname')
bow_1999 = pd.read_csv('/pathname')
bow_2000 = pd.read_csv('/pathname')
bow_2001 = pd.read_csv('/pathname')
bow_2002 = pd.read_csv('/pathname')
bow_2003 = pd.read_csv('/pathname')
bow_2004 = pd.read_csv('/pathname')
bow_2005 = pd.read_csv('/pathname')
bow_2006 = pd.read_csv('/pathname')
bow_2007 = pd.read_csv('/pathname')
bow_2008 = pd.read_csv('/pathname')
bow_2009 = pd.read_csv('/pathname')
bow_2010 = pd.read_csv('/pathname')
bow_2011 = pd.read_csv('/pathname')
bow_2012 = pd.read_csv('/pathname')
bow_2013 = pd.read_csv('/pathname')
bow_2014 = pd.read_csv('/pathname')
bow_2015 = pd.read_csv('/pathname')
bow_2016 = pd.read_csv('/pathname')
bow_2017 = pd.read_csv('/pathname')
bow_2018 = pd.read_csv('/pathname')
bow_2019 = pd.read_csv('/pathname')
bow_All = pd.read_csv(('/pathname')

# %%
#getting the counts of words in our bag of words for all words in the entire corpus

# %%
word_counts_bow_all = bow_All.sum(axis=0).sort_values(ascending=True)
word_counts_bow_1997 = bow_1997.sum(axis=0).sort_values(ascending=True)
word_counts_bow_1998 = bow_1998.sum(axis=0).sort_values(ascending=True)
word_counts_bow_1999 = bow_1999.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2000 = bow_2000.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2001 = bow_2001.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2002 = bow_2002.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2003 = bow_2003.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2004 = bow_2004.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2005 = bow_2005.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2006 = bow_2006.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2007 = bow_2007.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2008 = bow_2008.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2009 = bow_2009.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2010 = bow_2010.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2011 = bow_2011.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2012 = bow_2012.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2013 = bow_2013.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2014 = bow_2014.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2015 = bow_2015.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2016 = bow_2016.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2017 = bow_2017.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2018 = bow_2018.sum(axis=0).sort_values(ascending=True)
word_counts_bow_2019 = bow_2019.sum(axis=0).sort_values(ascending=True)

# %%
#returns the sum on word counts in the bag of words 
word_counts_bow_sum_all = word_counts_bow_all.sum()
word_counts_bow_sum_1997 = word_counts_bow_1997.sum()
word_counts_bow_sum_1998 = word_counts_bow_1998.sum()
word_counts_bow_sum_1999 = word_counts_bow_1999.sum()
word_counts_bow_sum_2000 = word_counts_bow_2000.sum()
word_counts_bow_sum_2001 = word_counts_bow_2001.sum()
word_counts_bow_sum_2002 = word_counts_bow_2002.sum()
word_counts_bow_sum_2003 = word_counts_bow_2003.sum()
word_counts_bow_sum_2004 = word_counts_bow_2004.sum()
word_counts_bow_sum_2005 = word_counts_bow_2005.sum()
word_counts_bow_sum_2006 = word_counts_bow_2006.sum()
word_counts_bow_sum_2007 = word_counts_bow_2007.sum()
word_counts_bow_sum_2008 = word_counts_bow_2008.sum()
word_counts_bow_sum_2009 = word_counts_bow_2009.sum()
word_counts_bow_sum_2010 = word_counts_bow_2010.sum()
word_counts_bow_sum_2011 = word_counts_bow_2011.sum()
word_counts_bow_sum_2012 = word_counts_bow_2012.sum()
word_counts_bow_sum_2013 = word_counts_bow_2013.sum()
word_counts_bow_sum_2014 = word_counts_bow_2014.sum()
word_counts_bow_sum_2015 = word_counts_bow_2015.sum()
word_counts_bow_sum_2016 = word_counts_bow_2016.sum()
word_counts_bow_sum_2017 = word_counts_bow_2017.sum()
word_counts_bow_sum_2018 = word_counts_bow_2018.sum()
word_counts_bow_sum_2019 = word_counts_bow_2019.sum()

# %%
# # Returns the percent sum over a DataFrame or Series axis.
# percentsum_bow_all = word_counts_bow_all/word_counts_bow_sum_all
# percentsum_bow_all.plot()

# %%
allWords = bow_All.keys()
allWords = allWords.drop('Unnamed: 0')

bow_list = [bow_1997,bow_1998,bow_1999,bow_2000,bow_2001,bow_2002,bow_2003,bow_2004,bow_2005,bow_2006,bow_2007,bow_2008,bow_2009,bow_2010,bow_2011,bow_2012,bow_2013,bow_2014,bow_2015,bow_2016,bow_2017,bow_2018,bow_2019]
allwords_per_year = np.zeros(len(bow_list))
counter = 0
for year in bow_list:
  for word in allWords:
    try:
      allwords_per_year[counter] += year[word].sum()
    except:
      continue
  counter += 1

print(allwords_per_year)
# Out:
# [2.400000e+01 4.930000e+02 2.524000e+03 1.451600e+04 2.317700e+04
#  3.395700e+04 4.266600e+04 7.797400e+04 6.895700e+04 9.198700e+04
#  1.657390e+05 1.463290e+05 1.765470e+05 3.167020e+05 3.263050e+05
#  3.747540e+05 4.336750e+05 4.910240e+05 5.470580e+05 6.095890e+05
#  6.029570e+05 6.073970e+05 2.972278e+06]

# %%
print(allWords)
# Out:
# Index(['abilities', 'address', 'age', 'aids', 'alias', 'analyze', 'ancestry',
#        'attitudes', 'audio', 'beacons', 'behavior', 'behavioral', 'biological',
#        'biometric', 'breastfeeding', 'cancer', 'characteristics', 'child',
#        'childbirth', 'chiropractic', 'citizenship', 'color', 'combination',
#        'condition', 'cookies', 'coordinates', 'dentistry', 'diagnosis',
#        'disability', 'dna', 'education', 'employment', 'ethnic', 'exercise',
#        'face', 'faceprint', 'family', 'fingerprint', 'fingerprints', 'gender',
#        'genetic', 'geolocation', 'hand', 'health', 'height', 'hiv',
#        'household', 'identified', 'identifiers', 'inferences', 'initials',
#        'intelligence', 'interests', 'iris', 'irises', 'language', 'latitude',
#        'locate', 'location', 'longitude', 'medicine', 'mental', 'movements',
#        'name', 'nursing', 'olfactory', 'optometry', 'origin', 'palm',
#        'password', 'passwords', 'patient', 'pharmacy', 'physical',
#        'physiological', 'podiatry', 'predict', 'predispositions',
#        'preferences', 'pregnancy', 'professional', 'profiling', 'race',
#        'racial', 'radius', 'reliability', 'religion', 'retina', 'sex',
#        'signature', 'sleep', 'thermal', 'visual', 'voice', 'voiceprint'],
#       dtype='object')

# %%
figure(figsize=(8, 12))

wordsOfInterest = ['']#, 'beacons','child','location','genetic','iris'.'behavioral','inference']

for word in allWords:
  freq_per_year = np.zeros(len(bow_list))
  counter = -1
  flag = False
  for year in bow_list:
    counter += 1
    try:
      freq_per_year[counter] = year[word].sum()/allwords_per_year[counter]
      lookbackdelay=7
      if counter > 0 and freq_per_year[counter]<0.15*freq_per_year[counter-1]:
        flag = True
      # if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and freq_per_year[counter]>10*freq_per_year[counter-lookbackdelay]:
      #   flag = True
      #if counter > 0 and  freq_per_year[counter-1]==0 and counter>20:
        #flag = True
    except:
      continue
  if word in wordsOfInterest or flag:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3)
    plt.text(2019.5, freq_per_year[-1]*(1+random.uniform(-0.5, 0.2)), word, color=plt.gca().lines[-1].get_color())
  else:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3,color='k',alpha=0.10)
plt.yscale('log')
plt.xlim(1997,2024)
#plt.ylim(1e-5,0.5)
plt.xlabel('year')
plt.ylabel('word frequency')
plt.title("PII word frequency in privacy policies 1997-2019: \n highlights words whose frequency falls more than 15% in a year")
plt.show()

# %%
figure(figsize=(8, 12))

wordsOfInterest = ['']#, 'beacons','child','location','genetic','iris'.'behavioral','inference']

for word in allWords:
  freq_per_year = np.zeros(len(bow_list))
  counter = -1
  flag = False
  for year in bow_list:
    counter += 1
    try:
      freq_per_year[counter] = year[word].sum()/allwords_per_year[counter]
      lookbackdelay=7
      # if counter > 0 and freq_per_year[counter]<0.15*freq_per_year[counter-1]:
      #   flag = True
      if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and freq_per_year[counter]>10*freq_per_year[counter-lookbackdelay]:
        flag = True
      #if counter > 0 and  freq_per_year[counter-1]==0 and counter>20:
        #flag = True
    except:
      continue
  if word in wordsOfInterest or flag:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3)
    plt.text(2019.5, freq_per_year[-1]*(1+random.uniform(-0.6, 0.2)), word, color=plt.gca().lines[-1].get_color())
  else:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3,color='k',alpha=0.10)
plt.yscale('log')
plt.xlim(1997,2024)
#plt.ylim(1e-5,0.5)
plt.xlabel('year')
plt.ylabel('word frequency')
plt.title("PII word frequency in privacy policies 1997-2019: \n highlights words whose frequency rises more than 10 times in 7 years")
plt.show()

# %%
figure(figsize=(8, 12))

wordsOfInterest = ['']#, 'beacons','child','location','genetic','iris'.'behavioral','inference']

for word in allWords:
  freq_per_year = np.zeros(len(bow_list))
  counter = -1
  flag = False
  for year in bow_list:
    counter += 1
    try:
      freq_per_year[counter] = year[word].sum()/allwords_per_year[counter]
      lookbackdelay=7
      # if counter > 0 and freq_per_year[counter]<0.15*freq_per_year[counter-1]:
      #   flag = True
      # if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and freq_per_year[counter]>10*freq_per_year[counter-lookbackdelay]:
      #   flag = True
      if counter > 0 and  freq_per_year[counter-1]==0 and counter>20:
        flag = True
    except:
      continue
  if word in wordsOfInterest or flag:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3)
    plt.text(2019.5, freq_per_year[-1]*(1+random.uniform(-0.6, 0.2)), word, color=plt.gca().lines[-1].get_color())
  else:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3,color='k',alpha=0.10)
plt.yscale('log')
plt.xlim(1997,2024)
#plt.ylim(1e-5,0.5)
plt.xlabel('year')
plt.ylabel('word frequency')
plt.title("PII word frequency in privacy policies 1997-2019: \n highlights words that newly emerge \n (occur 20 times after not occuring the previous year) ")
plt.show()

# %%
figure(figsize=(8, 10))

# wordsOfInterest = ['biometric', 'iris', 'retina', 'voice', 'voiceprint', 'face', 'olfactory', 'faceprint','audio', 'fingerprint', 'fingerprints', 'sleep', 'thermal'] 
wordsOfInterest = ['aids', 'medicine', 'health', 'patient', 'diagnosis', 'pharmacy','condition','pregnancy', 'mental', 'cancer','disability', 'genetic']
#, 'beacons','child','location','genetic','iris'.'behavioral','inference']

for word in allWords:
  freq_per_year = np.zeros(len(bow_list))
  counter = -1
  flag = False
  for year in bow_list:
    counter += 1
    try:
      freq_per_year[counter] = year[word].sum()/allwords_per_year[counter]
      lookbackdelay=7
      # if counter > 0 and freq_per_year[counter]<0.6*freq_per_year[counter-1]:
      #   flag = True
      # if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and freq_per_year[counter]>1*freq_per_year[counter-lookbackdelay]:
      #   flag = True
      # if counter > 0 and  freq_per_year[counter-1]==0 and counter>20:
      #   flag = True
    except:
      continue
  if word in wordsOfInterest or flag:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3)
    plt.text(2019.5, freq_per_year[-1]*(1+random.uniform(-0.6, 0.3)), word, color=plt.gca().lines[-1].get_color())
  else:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3,color='k',alpha=0.10)
plt.yscale('log')
plt.xlim(1997,2024)
# plt.ylim(1e-5,0.5)
plt.xlabel('year')
plt.ylabel('word frequency')
plt.title("PII word frequency in privacy policies 1997-2019: \n highlights words related to Health")
plt.show()

# %%
figure(figsize=(8, 10))


wordsOfInterest = ['location','locate','geolocation','latitude','longitude','coordinates','radius'] 

for word in allWords:
  freq_per_year = np.zeros(len(bow_list))
  counter = -1
  flag = False
  for year in bow_list:
    counter += 1
    try:
      freq_per_year[counter] = year[word].sum()/allwords_per_year[counter]
      lookbackdelay=7
      # if counter > 0 and freq_per_year[counter]<0.6*freq_per_year[counter-1]:
      #   flag = True
      # if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and freq_per_year[counter]>1*freq_per_year[counter-lookbackdelay]:
      #   flag = True
      # if counter > 0 and  freq_per_year[counter-1]==0 and counter>20:
      #   flag = True
    except:
      continue
  if word in wordsOfInterest or flag:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3)
    plt.text(2019.5, freq_per_year[-1]*(1+random.uniform(-0.6, 0.2)), word, color=plt.gca().lines[-1].get_color())
  else:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3,color='k',alpha=0.10)
plt.yscale('log')
plt.xlim(1997,2024)
# plt.ylim(1e-5,0.5)
plt.xlabel('year')
plt.ylabel('word frequency')
plt.title("PII word frequency in privacy policies 1997-2019: \n highlights words related to Location")
plt.show()

# %%
figure(figsize=(8, 12))

wordsOfInterest = ['']#, 'beacons','child','location','genetic','iris'.'behavioral','inference']

for word in allWords:
  freq_per_year = np.zeros(len(bow_list))
  counter = -1
  flag = False
  for year in bow_list:
    counter += 1
    try:
      freq_per_year[counter] = year[word].sum()/allwords_per_year[counter]
      lookbackdelay=20
      if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and abs(freq_per_year[counter]-freq_per_year[counter-lookbackdelay])<0.2*freq_per_year[counter]:
         flag = True
      # if counter > (lookbackdelay-1) and freq_per_year[counter-lookbackdelay]>0 and freq_per_year[counter]>10*freq_per_year[counter-lookbackdelay]:
      #   flag = True
      # if counter > 0 and  freq_per_year[counter-1]==0 and counter>20:
      #   flag = True
    except:
      continue
  #variance = np.var(freq_per_year)
  #mean = np.mean(freq_per_year)
  if word in wordsOfInterest or flag:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3)
    plt.text(2019.5, freq_per_year[-1]*(1+random.uniform(-0.2, 0.3)), word, color=plt.gca().lines[-1].get_color())
  else:
    plt.plot(np.arange(1997,2020),freq_per_year,ls='-',lw=3,color='k',alpha=0.10)
plt.yscale('log')
plt.xlim(1997,2024)
#plt.ylim(1e-5,0.5)
plt.xlabel('year')
plt.ylabel('word frequency')
plt.title("PII word frequency in privacy policies 1997-2019: \n highlights stable words")
plt.show()
